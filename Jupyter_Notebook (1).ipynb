# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mariana Monteiro** <br>
# Data Analyst

# %% [markdown]
# *I am interested in data science because it can help people's lives become better in so many ways!*

# %% [markdown]
# ### Run the code below and look how 1+1 returns 2 :)

# %%
1+1
# Out:
# 2

# %% [markdown]
# ---
#
# * bulleted list 1
# * bulleted list 2
#
# ---
#
# 1. one
# 2. two
# 3. three
#
# ---
#
# | Fact1 | Fact2| Fact3 |
# | --- | --- | --- |
# | I | ❤️ | Data |
#
# ---
#
# https://www.youtube.com/watch?v=y3-bfRpjV2s
#
# ---
#
# ![image.png](attachment:617dacfb-3a82-465f-801b-468ab0dd9237.png)
#
# ---
#
# test `highlighting` text
#
# ---
#
# > blocked quote1
#
# ---
#
# ~~strikethrougt~~
